# %% [markdown]
# # Mapa conocimiento 2.0

# %%
import os

# Averiguando ruta actual del notebook
ruta_actual = os.getcwd()

# Obtener la ruta de la carpeta "data"
ruta_data = os.path.join(os.path.dirname(ruta_actual), 'data')

# Cambiar el directorio actual a la carpeta "data"
os.chdir(ruta_data)

# Obtener la ruta de la carpeta "raw" dentro de "data"
ruta_raw = os.path.join(ruta_data, 'raw')

# Cambiar el directorio actual a la carpeta "raw"
os.chdir(ruta_raw)

# %%
ls
# Out:
# 00_MAPA_MISIONES_verificando.xlsx  00_MAPA_MISIONES.xlsx

# %%
import pandas as pd

# %%
completa = pd.read_excel("00_MAPA_MISIONES.xlsx")

# Se elimina columna que no se necesita
completa = completa.drop("Marca temporal", axis=1)

# Renombrando columnas
completa = completa.rename(columns={
    "Nombre y apellidos completos": "Nombre",
    "¿Cuál es tu numero de documento? (sin puntos)": "ID",
    "¿Cuál es tu edad?": "Edad",
    "¿Con qué genero te identificas más?": "Genero",
    "¿Cuál es tu profesión de base? ": "Profesion",
    "¿A qué unidad académica o administrativa pertenece?": "Unidad",
    "Seleccione los programas a los que se encuentra vinculado en la Facultad (en el que tiene mayor participación)": "Programa",
    "Seleccione la línea de investigación a la que pertenece si se encuentra en alguno de los grupos de investigación de la Facultad de Artes Integradas o en la que le gustaría participar. En caso de pertenecer a otra Facultad diligencie el nombre de la línea a la que pertenece": "Lin_Inv",
    "¿Cuál es su nivel de formación más alto? (ya graduado)": "Nivel_formac",
    "M1.1 - Diseño y desarrollo de productos sostenibles": "M1.1",
    "M1.2 - Arquitectura y urbanismo sostenible ": "M1.2",
    "M1.3 - Arte y educación ambiental": "M1.3",
    "M1.4 - Innovación tecnológica en la bioeconomía": "M1.4",
    "M1.5 - Diseño de espacios sostenibles ": "M1.5",
    "M1.6 - Biotecnología y bioingeniería": "M1.6",
    "M1.7 - Investigación en la biodiversidad y la conservación de ecosistemas naturales ": "M1.7",
    "M1.8 - Comunicación y marketing en la bioeconomía ": "M1.8",
    "M1.9 - Diseño de políticas públicas sostenibles": "M1.9",
    "M1.10 - Emprendimiento y creación de empresas sostenibles": "M1.10",
    "M2.1 - Diseño de espacios de producción de alimentos sostenibles": "M2.1",
    "M2.2 - Diseño de sistemas alimentarios sostenibles": "M2.2",
    "M2.3 - Arte y educación en seguridad alimentaria: ": "M2.3",
    "M2.4 - Arquitectura y diseño de espacios comunitarios de producción y consumo de alimentos": "M2.4",
    "M2.5 - Diseño de políticas públicas alimentarias": "M2.5",
    "M2.6 - Diseño de productos y envases alimentarios sostenibles": "M2.6",
    "M2.7 - Diseño de tecnologías alimentarias sostenibles": "M2.7",
    "M2.8 - Investigación sobre el impacto de la alimentación en la salud": "M2.8",
    "M2.9 - Diseño de estrategias de comunicación y marketing para promover el derecho a la alimentación": "M2.9",
    "M2.10 - Diseño de herramientas educativas para fomentar hábitos alimentarios saludables": "M2.10",
    "M3.1 - Diseño de edificios eficientes": "M3.1",
    "M3.2 - Diseño de infraestructuras sostenibles": "M3.2",
    "M3.3 - Diseño de sistemas de iluminación eficientes": "M3.3",
    "M3.4 - Arte y educación sobre energía sostenible": "M3.4",
    "M3.5 - Diseño de productos y dispositivos de energía renovable": "M3.5",
    "M3.6 - Diseño de políticas públicas energéticas": "M3.6",
    "M3.7 - Diseño de estrategias de comunicación y marketing para promover la energía sostenible": "M3.7",
    "M3.8 - Diseño de herramientas educativas para fomentar la eficiencia energética": "M3.8",
    "M3.9 - Investigación sobre el impacto de la energía en el medio ambiente": "M3.9",
    "M3.10 - Diseño de soluciones innovadoras para el almacenamiento de energía": "M3.10",
    "M4.1 - Diseño de infraestructuras sanitarias": "M4.1",
    "M4.2 - Diseño de espacios públicos saludables": "M4.2",
    "M4.3 - Diseño de soluciones innovadoras para la prevención de enfermedades": "M4.3",
    "M4.4 - Diseño de herramientas de comunicación para la promoción de la salud": "M4.4",
    "M4.5 - Arte y educación en salud": "M4.5",
    "M4.6 - Diseño de soluciones de vivienda saludable": "M4.6",
    "M4.7 - Diseño de soluciones innovadoras para la atención médica": "M4.7",
    "M4.8 - Diseño de soluciones para la movilidad sostenible": "M4.8",
    "M4.9 - Investigación sobre la relación entre la arquitectura y la salud": "M4.9",
    "M4.10 - Diseño de soluciones de accesibilidad": "M4.10",
    "M5.1 - Diseño de espacios para la convivencia pacífica": "M5.1",
    "M5.2 - Arte y cultura como herramientas para la reconciliación": "M5.2",
    "M5.3 - Diseño de soluciones para la inclusión social": "M5.3",
    "M5.4 - Arte y educación para la ciudadanía global": "M5.4",
    "M5.5 - Diseño de soluciones innovadoras para la resolución pacífica de conflictos": "M5.5",
    "M5.6 - Diseño de espacios de memoria y reparación": "M5.6",
    "M5.7 - Arte y cultura para la prevención de la violencia": "M5.7",
    "M5.8 - Diseño de soluciones para la seguridad ciudadana": "M5.8",
    "M5.9 - Investigación sobre la relación entre el arte, la arquitectura y la ciudadanía": "M5.9",
    "M5.10 - Diseño de soluciones para la participación ciudadana": "M5.10"
})

# Poniendo todos los nombres en mayúscula solo en el primer caracter
completa["Nombre"] = completa["Nombre"].str.title()

completa.head()
# Out:
#                         Nombre        ID          Edad     Genero
# 0  Carlos Manuel Bettin Karles  85452443  45 a 54 años  Masculino  \
# 1   Jorge Hugo Gutiérrez Díaz   94532236  35 a 44 años  Masculino
# 2        Marcelo Torres Arango  75064436  45 a 54 años  Masculino
# 3   Oscar Ramiro Murillo Ceron  94270087  35 a 44 años  Masculino
# 4         Felipe Villa Montoya  98558959  45 a 54 años  Masculino
#
#                 Profesion                        Unidad           Programa
# 0              Arquitecto  Facultad de Artes Integradas       Arquitectura  \
# 1               Diseñador  Facultad de Artes Integradas  Diseño Industrial
# 2  E ingeniero industrial  Facultad de Artes Integradas       Arquitectura
# 3               Diseñador  Facultad de Artes Integradas  Diseño Industrial
# 4              Arquitecto  Facultad de Artes Integradas       Arquitectura
#
#                            Lin_Inv     Nivel_formac  M1.1  ...  M5.1  M5.2
# ...

# %%
# Creando DF de la FAI sola/
fai = completa[completa["Unidad"] == "Facultad de Artes Integradas"]

# Eliminando a Marcelo pues le faltaron datos
fai =fai.drop(fai.loc[fai["Nombre"] == "Marcelo Torres Arango"].index)

fai.head()
# Out:
#                         Nombre        ID          Edad     Genero   Profesion
# 0  Carlos Manuel Bettin Karles  85452443  45 a 54 años  Masculino  Arquitecto  \
# 1   Jorge Hugo Gutiérrez Díaz   94532236  35 a 44 años  Masculino   Diseñador
# 3   Oscar Ramiro Murillo Ceron  94270087  35 a 44 años  Masculino   Diseñador
# 4         Felipe Villa Montoya  98558959  45 a 54 años  Masculino  Arquitecto
# 5   Nino Andrey Gaviria Puerta  71746645  45 a 54 años  Masculino  Arquitecto
#
#                          Unidad           Programa
# 0  Facultad de Artes Integradas       Arquitectura  \
# 1  Facultad de Artes Integradas  Diseño Industrial
# 3  Facultad de Artes Integradas  Diseño Industrial
# 4  Facultad de Artes Integradas       Arquitectura
# 5  Facultad de Artes Integradas       Arquitectura
#
#                            Lin_Inv     Nivel_formac  M1.1  ...  M5.1  M5.2
# 0  Factores humanos y bioclimática         Maestría    10  ...     8     8  \
# ...

# %%
fai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 41
# Data columns (total 59 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nombre        31 non-null     object
#  1   ID            31 non-null     int64
#  2   Edad          31 non-null     object
#  3   Genero        31 non-null     object
#  4   Profesion     31 non-null     object
#  5   Unidad        31 non-null     object
#  6   Programa      31 non-null     object
#  7   Lin_Inv       31 non-null     object
#  8   Nivel_formac  31 non-null     object
#  9   M1.1          31 non-null     int64
#  10  M1.2          31 non-null     int64
#  11  M1.3          31 non-null     int64
#  12  M1.4          31 non-null     int64
#  13  M1.5          31 non-null     int64
#  14  M1.6          31 non-null     int64
#  15  M1.7          31 non-null     int64
#  16  M1.8          31 non-null     int64
#  17  M1.9          31 non-null     int64
# ...

# %%
# Creando columnas para sumar votos de misiones
col_m1 = fai.filter(regex=r'^M1').columns
suma_columnas_m1 = fai[col_m1].sum(axis=1)
suma_columnas_m1

col_m2 = fai.filter(regex=r'^M2').columns
suma_columnas_m2 = fai[col_m2].sum(axis=1)
suma_columnas_m2

col_m3 = fai.filter(regex=r'^M3').columns
suma_columnas_m3 = fai[col_m3].sum(axis=1)
suma_columnas_m3

col_m4 = fai.filter(regex=r'^M4').columns
suma_columnas_m4 = fai[col_m4].sum(axis=1)
suma_columnas_m4

col_m5 = fai.filter(regex=r'^M5').columns
suma_columnas_m5 = fai[col_m5].sum(axis=1)
suma_columnas_m5



# Llevando series independientes al Dataframe
fai = fai.join([suma_columnas_m1.rename('suma_m1_psna'), 
                suma_columnas_m2.rename('suma_m2_psna'), 
                suma_columnas_m3.rename('suma_m3_psna'), 
                suma_columnas_m4.rename('suma_m4_psna'), 
                suma_columnas_m5.rename('suma_m5_psna')])




# Sumar los valores de las columnas en cada fila
fai['suma_total_psna'] = fai[['suma_m1_psna', 
                              'suma_m2_psna', 
                              'suma_m3_psna', 
                              'suma_m4_psna', 
                              'suma_m5_psna']].sum(axis=1)

# Calcular el porcentaje de cada valor con relación a la suma total y redondear esa cantidad a una sola cifra
fai['porc_m1_psna'] = (fai['suma_m1_psna'] / fai['suma_total_psna'] * 100).round(1)
fai['porc_m2_psna'] = (fai['suma_m2_psna'] / fai['suma_total_psna'] * 100).round(1)
fai['porc_m3_psna'] = (fai['suma_m3_psna'] / fai['suma_total_psna'] * 100).round(1)
fai['porc_m4_psna'] = (fai['suma_m4_psna'] / fai['suma_total_psna'] * 100).round(1)
fai['porc_m5_psna'] = (fai['suma_m5_psna'] / fai['suma_total_psna'] * 100).round(1)


fai
# Out:
#                                Nombre          ID          Edad     Genero
# 0         Carlos Manuel Bettin Karles    85452443  45 a 54 años  Masculino  \
# 1          Jorge Hugo Gutiérrez Díaz     94532236  35 a 44 años  Masculino
# 3          Oscar Ramiro Murillo Ceron    94270087  35 a 44 años  Masculino
# 4                Felipe Villa Montoya    98558959  45 a 54 años  Masculino
# 5          Nino Andrey Gaviria Puerta    71746645  45 a 54 años  Masculino
# 6               María Del Mar Cancino  1094941443  25 a 34 años   Femenino
# 7      Carlos Alberto Castaño Aguirre  1094907537  25 a 34 años  Masculino
# 8                 Ricardo De Los Rios    13068727  35 a 44 años  Masculino
# 9         Yury Andrea Hernández Duque  1128397576  25 a 34 años   Femenino
# 10         Alba Stefania Gómez Gómez   1020449277  25 a 34 años   Femenino
# 11       Carlos Alberto Mejía Barrera    98701292  35 a 44 años  Masculino
# ...

# %% [markdown]
# <br>
# <br>
#
# ## Perfil general FAI

# %%
# Creando DF resumen de FAI
df_fai_perfil = fai.groupby("Unidad")[['suma_m1_psna', 'suma_m2_psna', 'suma_m3_psna', 'suma_m4_psna', 'suma_m5_psna']].sum()

# Renombrando columnas
df_fai_perfil = df_fai_perfil.rename(columns={
    "suma_m1_psna": "suma_m1_fai",
    "suma_m2_psna": "suma_m2_fai",
    "suma_m3_psna": "suma_m3_fai",
    "suma_m4_psna": "suma_m4_fai",
    "suma_m5_psna": "suma_m5_fai"
})

# Sumar los valores de las columnas en cada fila
df_fai_perfil['suma_total_fai'] = df_fai_perfil[['suma_m1_fai', 
                              'suma_m2_fai', 
                              'suma_m3_fai', 
                              'suma_m4_fai', 
                              'suma_m5_fai']].sum(axis=1)

# Calcular el porcentaje de cada valor con relación a la suma total y redondear esa cantidad a una sola cifra
df_fai_perfil['porc_m1_fai'] = (df_fai_perfil['suma_m1_fai'] / df_fai_perfil['suma_total_fai'] * 100).round(1)
df_fai_perfil['porc_m2_fai'] = (df_fai_perfil['suma_m2_fai'] / df_fai_perfil['suma_total_fai'] * 100).round(1)
df_fai_perfil['porc_m3_fai'] = (df_fai_perfil['suma_m3_fai'] / df_fai_perfil['suma_total_fai'] * 100).round(1)
df_fai_perfil['porc_m4_fai'] = (df_fai_perfil['suma_m4_fai'] / df_fai_perfil['suma_total_fai'] * 100).round(1)
df_fai_perfil['porc_m5_fai'] = (df_fai_perfil['suma_m5_fai'] / df_fai_perfil['suma_total_fai'] * 100).round(1)


df_fai_perfil
# Out:
#                               suma_m1_fai  suma_m2_fai  suma_m3_fai
# Unidad
# Facultad de Artes Integradas         2276         1707         2267  \
#
#                               suma_m4_fai  suma_m5_fai  suma_total_fai
# Unidad
# Facultad de Artes Integradas         2157         2340           10747  \
#
#                               porc_m1_fai  porc_m2_fai  porc_m3_fai
# Unidad
# Facultad de Artes Integradas         21.2         15.9         21.1  \
#
#                               porc_m4_fai  porc_m5_fai
# Unidad
# Facultad de Artes Integradas         20.1         21.8

# %% [markdown]
# <br>
# <br>
#
# ## Línea de investigación

# %%
# Creando DF con suma de valores por misión según línea de investigación
df_lin_inv = fai.groupby('Lin_Inv')[['suma_m1_psna', 'suma_m2_psna', 'suma_m3_psna', 'suma_m4_psna', 'suma_m5_psna']].sum()


# Renombrando columnas
df_lin_inv = df_lin_inv.rename(columns={
    "suma_m1_psna": "suma_m1_linInv",
    "suma_m2_psna": "suma_m2_linInv",
    "suma_m3_psna": "suma_m3_linInv",
    "suma_m4_psna": "suma_m4_linInv",
    "suma_m5_psna": "suma_m5_linInv"
})

# Sumar los valores de las columnas en cada fila
df_lin_inv['suma_total_linInv'] = df_lin_inv[['suma_m1_linInv', 
                              'suma_m2_linInv', 
                              'suma_m3_linInv', 
                              'suma_m4_linInv', 
                              'suma_m5_linInv']].sum(axis=1)

# Calcular el porcentaje de cada valor con relación a la suma total y redondear esa cantidad a una sola cifra
df_lin_inv['porc_m1_linInv'] = (df_lin_inv['suma_m1_linInv'] / df_lin_inv['suma_total_linInv'] * 100).round(1)
df_lin_inv['porc_m2_linInv'] = (df_lin_inv['suma_m2_linInv'] / df_lin_inv['suma_total_linInv'] * 100).round(1)
df_lin_inv['porc_m3_linInv'] = (df_lin_inv['suma_m3_linInv'] / df_lin_inv['suma_total_linInv'] * 100).round(1)
df_lin_inv['porc_m4_linInv'] = (df_lin_inv['suma_m4_linInv'] / df_lin_inv['suma_total_linInv'] * 100).round(1)
df_lin_inv['porc_m5_linInv'] = (df_lin_inv['suma_m5_linInv'] / df_lin_inv['suma_total_linInv'] * 100).round(1)


df_lin_inv
# Out:
#                                                     suma_m1_linInv
# Lin_Inv
# A varios de los anteriores. Factores humanos, d...              75  \
# Estética y creación                                            389
# Factores humanos y bioclimática                                480
# Hábitat sustentable                                             82
# Hábitat y medio ambiente                                       308
# Memoria, identidad y cultura                                   455
# Tecnología                                                     487
#
#                                                     suma_m2_linInv
# Lin_Inv
# A varios de los anteriores. Factores humanos, d...              14  \
# Estética y creación                                            321
# Factores humanos y bioclimática                                407
# Hábitat sustentable                                             59
# Hábitat y medio ambiente                                       238
# ...

# %%
# Generando DF's independientes por línea de investigación
lineas = fai.groupby('Lin_Inv')

df_lineas = []

for valor, grupo in lineas:
    df_independiente = grupo.copy()
    df_lineas.append(df_independiente)

# %%
df_lineas[0]
# Out:
#                Nombre       ID          Edad     Genero   Profesion
# 30  Lucas Arango Diaz  8127790  35 a 44 años  Masculino  Arquitecto  \
#
#                           Unidad                  Programa
# 30  Facultad de Artes Integradas  Maestría en Bioclimática  \
#
#                                               Lin_Inv Nivel_formac  M1.1  ...
# 30  A varios de los anteriores. Factores humanos, ...    Doctorado    10  ...  \
#
#     suma_m2_psna  suma_m3_psna  suma_m4_psna  suma_m5_psna  suma_total_psna
# 30            14           100            64            14              267  \
#
#     porc_m1_psna  porc_m2_psna  porc_m3_psna  porc_m4_psna  porc_m5_psna
# 30          28.1           5.2          37.5          24.0           5.2
#
# [1 rows x 70 columns]

# %%
df_estCreac = df_lineas[1]
df_estCreac
# Out:
#                             Nombre          ID          Edad    Genero
# 10      Alba Stefania Gómez Gómez   1020449277  25 a 34 años  Femenino  \
# 13          Alejandra Gómez Vélez   1017178082  25 a 34 años  Femenino
# 23       Maria Isabel Naranjo Cano    43616112  45 a 54 años  Femenino
# 31  Karol.Ibarra@Tau.Usbmed.Edu.Co    36758911  35 a 44 años  Femenino
# 34     Sandra Elena Carrión Suárez    32105478  45 a 54 años  Femenino
#
#            Profesion                        Unidad                  Programa
# 10        Arquitecto  Facultad de Artes Integradas              Arquitectura  \
# 13  Artista plástico  Facultad de Artes Integradas   Maestría en Creatividad
# 23  Artista plástico  Facultad de Artes Integradas   Maestría en Creatividad
# 31         Diseñador  Facultad de Artes Integradas         Diseño Industrial
# 34        Arquitecto  Facultad de Artes Integradas  Maestría en Bioclimática
#
#                 Lin_Inv     Nivel_formac  M1.1  ...  suma_m2_psna
# ...

# %%
df_factHumBiocl = df_lineas[2]
df_factHumBiocl
# Out:
#                                Nombre          ID          Edad     Genero
# 0         Carlos Manuel Bettin Karles    85452443  45 a 54 años  Masculino  \
# 6               María Del Mar Cancino  1094941443  25 a 34 años   Femenino
# 9         Yury Andrea Hernández Duque  1128397576  25 a 34 años   Femenino
# 19  Alejandro Antonio Naranjo Gaviria     8164327  35 a 44 años  Masculino
# 35          Elisabeth Herreño Téllez     52316367  45 a 54 años   Femenino
# 39            Elizabeth Parra Correa   1053817088  25 a 34 años   Femenino
#
#      Profesion                        Unidad                  Programa
# 0   Arquitecto  Facultad de Artes Integradas              Arquitectura  \
# 6   Arquitecto  Facultad de Artes Integradas              Arquitectura
# 9   Arquitecto  Facultad de Artes Integradas              Arquitectura
# 19  Arquitecto  Facultad de Artes Integradas  Maestría en Bioclimática
# 35   Diseñador  Facultad de Artes Integradas         Diseño Industrial
# ...

# %%
df_habSustent = df_lineas[3]
df_habSustent
# Out:
#                       Nombre          ID          Edad    Genero   Profesion
# 37  Valentina Zuluaga Puerta  1152209663  25 a 34 años  Femenino  Arquitecto  \
#
#                           Unidad      Programa              Lin_Inv
# 37  Facultad de Artes Integradas  Arquitectura  Hábitat sustentable  \
#
#    Nivel_formac  M1.1  ...  suma_m2_psna  suma_m3_psna  suma_m4_psna
# 37     Pregrado     8  ...            59            89            91  \
#
#     suma_m5_psna  suma_total_psna  porc_m1_psna  porc_m2_psna  porc_m3_psna
# 37            93              414          19.8          14.3          21.5  \
#
#     porc_m4_psna  porc_m5_psna
# 37          22.0          22.5
#
# [1 rows x 70 columns]

# %%
df_habMedAmb = df_lineas[4]
df_habMedAmb
# Out:
#                             Nombre          ID          Edad     Genero
# 7   Carlos Alberto Castaño Aguirre  1094907537  25 a 34 años  Masculino  \
# 20          Pablo Echeverri Rendón    71627215  55 a 64 años  Masculino
# 22       Diana Elizabeth Valencia     43523188  45 a 54 años   Femenino
# 36        Carolina Velásquez Gómez    24331769  35 a 44 años   Femenino
# 38   Carlos Alberto Marín Herrera     86056154  45 a 54 años  Masculino
#
#      Profesion                        Unidad      Programa
# 7   Arquitecto  Facultad de Artes Integradas  Arquitectura  \
# 20  Arquitecto  Facultad de Artes Integradas  Arquitectura
# 22  Arquitecto  Facultad de Artes Integradas  Arquitectura
# 36  Arquitecto  Facultad de Artes Integradas  Arquitectura
# 38  Arquitecto  Facultad de Artes Integradas  Arquitectura
#
#                      Lin_Inv     Nivel_formac  M1.1  ...  suma_m2_psna
# 7   Hábitat y medio ambiente         Maestría     3  ...            21  \
# ...

# %%
df_memoIdCult = df_lineas[5]
df_memoIdCult
# Out:
#                         Nombre          ID          Edad     Genero
# 4         Felipe Villa Montoya    98558959  45 a 54 años  Masculino  \
# 5   Nino Andrey Gaviria Puerta    71746645  45 a 54 años  Masculino
# 8          Ricardo De Los Rios    13068727  35 a 44 años  Masculino
# 24   Ivan Dario Garcia Ordoñez    18468387  35 a 44 años  Masculino
# 27           Mauricio Cano Gil    98558270  45 a 54 años  Masculino
# 29     David Cadavid Castaneda  1152191155  25 a 34 años  Masculino
# 41     Eleazar Gomez Fernandez    71743944  45 a 54 años  Masculino
#
#      Profesion                        Unidad           Programa
# 4   Arquitecto  Facultad de Artes Integradas       Arquitectura  \
# 5   Arquitecto  Facultad de Artes Integradas       Arquitectura
# 8    Diseñador  Facultad de Artes Integradas  Diseño Industrial
# 24  Arquitecto  Facultad de Artes Integradas       Arquitectura
# 27  Arquitecto  Facultad de Artes Integradas       Arquitectura
# ...

# %%
df_tecnol = df_lineas[6]
df_tecnol
# Out:
#                           Nombre        ID          Edad     Genero
# 1     Jorge Hugo Gutiérrez Díaz   94532236  35 a 44 años  Masculino  \
# 3     Oscar Ramiro Murillo Ceron  94270087  35 a 44 años  Masculino
# 11  Carlos Alberto Mejía Barrera  98701292  35 a 44 años  Masculino
# 17             Juan Pablo Arango  71776871  45 a 54 años  Masculino
# 21     Luis Javier Sierra Arango  70564290  55 a 64 años  Masculino
# 28        Juliana Ortiz Carvajal  41962117  35 a 44 años   Femenino
#
#      Profesion                        Unidad
# 1    Diseñador  Facultad de Artes Integradas  \
# 3    Diseñador  Facultad de Artes Integradas
# 11  Arquitecto  Facultad de Artes Integradas
# 17   Ingeniero  Facultad de Artes Integradas
# 21  Arquitecto  Facultad de Artes Integradas
# 28  Arquitecto  Facultad de Artes Integradas
#
#                                              Programa     Lin_Inv
# 1                                   Diseño Industrial  Tecnología  \
# ...
